# %%
import pandas as pd
import time
from pprint import pprint
from GOOGLE import Create_Service

CLIENT_SECRET_FILE = 'credentials_desktop.json'
# tasks_API_NAME = 'tasks'
# tasks_API_VERSION = 'v1'
# tasks_SCOPES = ["https://www.googleapis.com/auth/tasks"]
# tasks_service = Create_Service(CLIENT_SECRET_FILE, tasks_API_NAME, tasks_API_VERSION, tasks_SCOPES)

sheets_API_NAME = 'sheets'
sheets_API_VERSION = 'v4'
sheets_SCOPES = ["https://www.googleapis.com/auth/spreadsheets"]
sheets_service = Create_Service(CLIENT_SECRET_FILE, sheets_API_NAME, sheets_API_VERSION, sheets_SCOPES)

my_tasks_list_id = 'MDIzMjY3NDgxNTg0OTU4ODE2ODc6MDow'
games_list_id = "X08wOUJ2THZGeEhhYVRkUQ"

SPREADSHEET_ID = "1wIS4jNhBDNgmFwlu8h344NSbosh_DqEzlXVf4Nmfyko"
sheets_data = sheets_service.spreadsheets().values().get(
                            spreadsheetId=SPREADSHEET_ID,
                            range="TO DO!C6:G26",
                            ).execute()
# Out:
# credentials_desktop.json-sheets-v4-(['https://www.googleapis.com/auth/spreadsheets'],)
# ['https://www.googleapis.com/auth/spreadsheets']
# sheets service created successfully

# %%
df = pd.DataFrame(sheets_data['values'][1:], columns=sheets_data['values'][0])
df
# Out:
#      Done                                      Task           Due Date  \
# 0   FALSE              Plot your office PINS on MAP
# 1   FALSE                       PACE MNC Chandrapur   Fri, Dec 1, 2023
# 2   FALSE               PACE Amravati Div PWD & WRD               None
# 3   FALSE                                  PACE MJP   Sat, Dec 9, 2023
# 4   FALSE                      Google Drive API, E4
# 5   FALSE      What do I do with the filter glitch?  Thu, Nov 30, 2023
# 6   FALSE                    Is that even a glitch?  Thu, Nov 30, 2023
# 7   FALSE                                      None               None
# 8   FALSE                                      None               None
# 9   FALSE                                PDF Reader  Fri, Dec 15, 2023
# 10   TRUE                      Add / Update Tenders   Fri, Nov 3, 2023
# 11  FALSE                      Rectify your Methods   Sat, Dec 2, 2023
# 12  FALSE                          Justdial Program  Sun, Dec 10, 2023
# 13  FALSE                                      None               None
# 14  FALSE                                      None               None
# 15  FALSE                                      None               None
# 16  FALSE          Find a solution for DATA STORAGE  Thu, Dec 14, 2023
# 17  FALSE                  BigQuery is the new KING  Thu, Nov 30, 2023
# 18  FALSE                           Spotify Scraper   Wed, Dec 6, 2023
# 19  FALSE  Integrate this sheet and Google Calendar  Thu, Nov 30, 2023
#
#            Status Days Left
# 0          Paused      None
# 1     In Progress         3
# 2            None      None
# 3                        11
# 4          Paused      None
# 5         Pending         2
# 6         Pending         2
# 7            None      None
# 8            None      None
# 9          Paused        17
# 10                      -25
# 11  Halfway There         4
# 12    In Progress        12
# 13           None      None
# 14           None      None
# 15           None      None
# 16    In Progress        16
# 17  Halfway There         2
# 18         Paused         8
# 19  Halfway There         2

# %%
df['Due Date'] = pd.to_datetime(df['Due Date'])
df
# Out:
#      Done                                      Task   Due Date         Status  \
# 0   FALSE              Plot your office PINS on MAP        NaT         Paused
# 1   FALSE                       PACE MNC Chandrapur 2023-12-01    In Progress
# 2   FALSE               PACE Amravati Div PWD & WRD        NaT           None
# 3   FALSE                                  PACE MJP 2023-12-09
# 4   FALSE                      Google Drive API, E4        NaT         Paused
# 5   FALSE      What do I do with the filter glitch? 2023-11-30        Pending
# 6   FALSE                    Is that even a glitch? 2023-11-30        Pending
# 7   FALSE                                      None        NaT           None
# 8   FALSE                                      None        NaT           None
# 9   FALSE                                PDF Reader 2023-12-15         Paused
# 10   TRUE                      Add / Update Tenders 2023-11-03
# 11  FALSE                      Rectify your Methods 2023-12-02  Halfway There
# 12  FALSE                          Justdial Program 2023-12-10    In Progress
# 13  FALSE                                      None        NaT           None
# 14  FALSE                                      None        NaT           None
# 15  FALSE                                      None        NaT           None
# 16  FALSE          Find a solution for DATA STORAGE 2023-12-14    In Progress
# 17  FALSE                  BigQuery is the new KING 2023-11-30  Halfway There
# 18  FALSE                           Spotify Scraper 2023-12-06         Paused
# 19  FALSE  Integrate this sheet and Google Calendar 2023-11-30  Halfway There
#
#    Days Left
# 0       None
# 1          3
# 2       None
# 3         11
# 4       None
# 5          2
# 6          2
# 7       None
# 8       None
# 9         17
# 10       -25
# 11         4
# 12        12
# 13      None
# 14      None
# 15      None
# 16        16
# 17         2
# 18         8
# 19         2

# %%
due_tasks = df.loc[(df['Done'] == "FALSE") & (df['Due Date'].notna())]
due_tasks
# Out:
#      Done                                      Task   Due Date         Status  \
# 1   FALSE                       PACE MNC Chandrapur 2023-12-01    In Progress
# 3   FALSE                                  PACE MJP 2023-12-09
# 5   FALSE      What do I do with the filter glitch? 2023-11-30        Pending
# 6   FALSE                    Is that even a glitch? 2023-11-30        Pending
# 9   FALSE                                PDF Reader 2023-12-15         Paused
# 11  FALSE                      Rectify your Methods 2023-12-02  Halfway There
# 12  FALSE                          Justdial Program 2023-12-10    In Progress
# 16  FALSE          Find a solution for DATA STORAGE 2023-12-14    In Progress
# 17  FALSE                  BigQuery is the new KING 2023-11-30  Halfway There
# 18  FALSE                           Spotify Scraper 2023-12-06         Paused
# 19  FALSE  Integrate this sheet and Google Calendar 2023-11-30  Halfway There
#
#    Days Left
# 1          3
# 3         11
# 5          2
# 6          2
# 9         17
# 11         4
# 12        12
# 16        16
# 17         2
# 18         8
# 19         2

# %%
new_tasks = []
for row in due_tasks.iterrows():
    # print(row[1][['Task', 'Due Date', 'Status']])
    task = {
    'title': row[1]['Task'],
    'notes': row[1]['Status'],
    'due': row[1]['Due Date']
    }
    new_tasks.append(task)

# %%
new_tasks
# Out:
# [{'title': 'PACE MNC Chandrapur',
#   'notes': 'In Progress',
#   'due': Timestamp('2023-12-01 00:00:00')},
#  {'title': 'PACE MJP', 'notes': '', 'due': Timestamp('2023-12-09 00:00:00')},
#  {'title': 'What do I do with the filter glitch?',
#   'notes': 'Pending',
#   'due': Timestamp('2023-11-30 00:00:00')},
#  {'title': 'Is that even a glitch?',
#   'notes': 'Pending',
#   'due': Timestamp('2023-11-30 00:00:00')},
#  {'title': 'PDF Reader',
#   'notes': 'Paused',
#   'due': Timestamp('2023-12-15 00:00:00')},
#  {'title': 'Rectify your Methods',
#   'notes': 'Halfway There',
#   'due': Timestamp('2023-12-02 00:00:00')},
#  {'title': 'Justdial Program',
#   'notes': 'In Progress',
#   'due': Timestamp('2023-12-10 00:00:00')},
#  {'title': 'Find a solution for DATA STORAGE',
#   'notes': 'In Progress',
#   'due': Timestamp('2023-12-14 00:00:00')},
#  {'title': 'BigQuery is the new KING',
#   'notes': 'Halfway There',
#   'due': Timestamp('2023-11-30 00:00:00')},
#  {'title': 'Spotify Scraper',
#   'notes': 'Paused',
#   'due': Timestamp('2023-12-06 00:00:00')},
#  {'title': 'Integrate this sheet and Google Calendar',
#   'notes': 'Halfway There',
#   'due': Timestamp('2023-11-30 00:00:00')}]
